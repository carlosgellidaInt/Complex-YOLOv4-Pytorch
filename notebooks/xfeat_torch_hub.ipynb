# %% [markdown]
# # XFeat matching example using torch hub

# %% [markdown]
# ## Initialize XFeat

# %%
import numpy as np
import imageio as imio
import os
import torch
import tqdm
import cv2
import matplotlib.pyplot as plt

xfeat = torch.hub.load('verlab/accelerated_features', 'XFeat', pretrained = True, top_k = 4096)

print(os.listdir())
#Load some example images
im1 = np.copy(imio.v2.imread('good_product3.png')[..., ::-1])
im2 = np.copy(imio.v2.imread('product5.png')[..., ::-1])
# Out:
# ['.config', 'only_product.jpg', '.ipynb_checkpoints', 'good_product1.png', 'test3.jpg', 'product3.jpg', 'good_product3.png', 'product5.png', 'test1.jpg', 'launch.jpg', 'test4.jpg', 'images.jpg', 'product1.jpg', 'good_product2.png', 'test5.jpg', 'sample_data']
# Using cache found in /root/.cache/torch/hub/verlab_accelerated_features_main

# %% [markdown]
# ## Simple function that fits an homography in a set of matches and draw the homography transform

# %%
import cv2
import numpy as np

def warp_corners_and_draw_matches(ref_points, dst_points, img1, img2):
    # Calculate the Homography matrix
    H, mask = cv2.findHomography(ref_points, dst_points, cv2.USAC_MAGSAC, 3.5, maxIters=1_000, confidence=0.999)
    mask = mask.flatten()

    # Get corners of the first image (image1)
    h, w = img1.shape[:2]
    corners_img1 = np.array([[0, 0], [w-1, 0], [w-1, h-1], [0, h-1]], dtype=np.float32).reshape(-1, 1, 2)

    # Warp corners to the second image (image2) space
    warped_corners = cv2.perspectiveTransform(corners_img1, H)

    # Draw the warped corners in image2
    img2_with_corners = img2.copy()
    for i in range(len(warped_corners)):
        start_point = tuple(warped_corners[i-1][0].astype(int))
        end_point = tuple(warped_corners[i][0].astype(int))
        cv2.line(img2_with_corners, start_point, end_point, (0, 255, 0), 4)  # Using solid green for corners

    # Prepare keypoints and matches for drawMatches function
    keypoints1 = [cv2.KeyPoint(p[0], p[1], 5) for p in ref_points]
    keypoints2 = [cv2.KeyPoint(p[0], p[1], 5) for p in dst_points]
    matches = [cv2.DMatch(i,i,0) for i in range(len(mask)) if mask[i]]

    # Draw inlier matches
    img_matches = cv2.drawMatches(img1, keypoints1, img2_with_corners, keypoints2, matches, None,
                                  matchColor=(0, 255, 0), flags=2)

    return img_matches

# %% [markdown]
# ## Matching example - sparse setting

# %%
#Use out-of-the-box function for extraction + MNN matching
mkpts_0, mkpts_1 = xfeat.match_xfeat(im1, im2, top_k = 4096)

canvas = warp_corners_and_draw_matches(mkpts_0, mkpts_1, im1, im2)
plt.figure(figsize=(12,12))
plt.imshow(canvas[..., ::-1]), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7cee8bb28310>, None)

# %% [markdown]
# ## Matching example - Semi-dense setting

# %%
#Use out-of-the-box function for extraction + coarse-to-fine matching
mkpts_0, mkpts_1 = xfeat.match_xfeat_star(im1, im2, top_k = 8000)

canvas = warp_corners_and_draw_matches(mkpts_0, mkpts_1, im1, im2)
plt.figure(figsize=(12,12))
plt.imshow(canvas[..., ::-1]), plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-45-b872bbc621c3> in <cell line: 0>()
#       1 #Use out-of-the-box function for extraction + coarse-to-fine matching
# ----> 2 mkpts_0, mkpts_1 = xfeat.match_xfeat_star(im1, im2, top_k = 8000)
#       3
#       4 canvas = warp_corners_and_draw_matches(mkpts_0, mkpts_1, im1, im2)
#       5 plt.figure(figsize=(12,12))
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# ~/.cache/torch/hub/verlab_accelerated_features_main/modules/xfeat.py in match_xfeat_star(self, im_set1, im_set2, top_k)
#     202
#     203                 #Compute coarse feats
# --> 204                 out1 = self.detectAndComputeDense(im_set1, top_k=top_k)
#     205                 out2 = self.detectAndComputeDense(im_set2, top_k=top_k)
#     206
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# ~/.cache/torch/hub/verlab_accelerated_features_main/modules/xfeat.py in detectAndComputeDense(self, x, top_k, multiscale)
#     119                 if top_k is None: top_k = self.top_k
#     120                 if multiscale:
# --> 121                         mkpts, sc, feats = self.extract_dualscale(x, top_k)
#     122                 else:
#     123                         mkpts, feats = self.extractDense(x, top_k)
#
# ~/.cache/torch/hub/verlab_accelerated_features_main/modules/xfeat.py in extract_dualscale(self, x, top_k, s1, s2)
#     383                 B, _, _, _ = x.shape
#     384
# --> 385                 mkpts_1, feats_1 = self.extractDense(x1, int(top_k*0.20))
#     386                 mkpts_2, feats_2 = self.extractDense(x2, int(top_k*0.80))
#     387
#
# ~/.cache/torch/hub/verlab_accelerated_features_main/modules/xfeat.py in extractDense(self, x, top_k)
#     358                         top_k = 100_000_000
#     359
# --> 360                 x, rh1, rw1 = self.preprocess_tensor(x)
#     361
#     362                 M1, K1, H1 = self.net(x)
#
# ~/.cache/torch/hub/verlab_accelerated_features_main/modules/xfeat.py in preprocess_tensor(self, x)
#     235                 H, W = x.shape[-2:]
#     236                 _H, _W = (H//32) * 32, (W//32) * 32
# --> 237                 rh, rw = H/_H, W/_W
#     238
#     239                 x = F.interpolate(x, (_H, _W), mode='bilinear', align_corners=False)
#
# ZeroDivisionError: division by zero
